# %%
from utils.coin_validator import WeeklyData

data = {
    "uniswap": {
        1: WeeklyData(
            weekly_high=[1655337600000, 342], weekly_low=[1655625380000, 279]
        ),
        2: WeeklyData(
            weekly_high=[1654560000000, 418], weekly_low=[1655078400000, 321]
        ),
        3: WeeklyData(
            weekly_high=[1654041600000, 442], weekly_low=[1654300800000, 394]
        ),
        4: WeeklyData(
            weekly_high=[1653350400000, 436], weekly_low=[1653696000000, 363]
        ),
        5: WeeklyData(
            weekly_high=[1653264000000, 429], weekly_low=[1652918400000, 380]
        ),
        6: WeeklyData(
            weekly_high=[1652227200000, 468], weekly_low=[1652400000000, 362]
        ),
        7: WeeklyData(
            weekly_high=[1651708800000, 605], weekly_low=[1651622400000, 524]
        ),
        8: WeeklyData(
            weekly_high=[1650931200000, 669], weekly_low=[1651363200000, 520]
        ),
        9: WeeklyData(
            weekly_high=[1650412800000, 729], weekly_low=[1650844800000, 665]
        ),
        10: WeeklyData(
            weekly_high=[1650067200000, 746], weekly_low=[1649721600000, 680]
        ),
        11: WeeklyData(
            weekly_high=[1649116800000, 868], weekly_low=[1649462400000, 736]
        ),
        12: WeeklyData(
            weekly_high=[1649030400000, 899], weekly_low=[1648512000000, 829]
        ),
        13: WeeklyData(
            weekly_high=[1648425600000, 867], weekly_low=[1647907200000, 712]
        ),
        14: WeeklyData(
            weekly_high=[1647734400000, 736], weekly_low=[1647302400000, 648]
        ),
        15: WeeklyData(
            weekly_high=[1646870400000, 700], weekly_low=[1647216000000, 628]
        ),
        16: WeeklyData(
            weekly_high=[1646092800000, 792], weekly_low=[1646611200000, 648]
        ),
        17: WeeklyData(
            weekly_high=[1646006400000, 738], weekly_low=[1645488000000, 641]
        ),
        18: WeeklyData(
            weekly_high=[1644969600000, 861], weekly_low=[1645401600000, 700]
        ),
        19: WeeklyData(
            weekly_high=[1644278400000, 927], weekly_low=[1644796800000, 784]
        ),
        20: WeeklyData(
            weekly_high=[1643673600000, 881], weekly_low=[1643932800000, 774]
        ),
        21: WeeklyData(
            weekly_high=[1643500800000, 837], weekly_low=[1643328000000, 778]
        ),
        22: WeeklyData(
            weekly_high=[1642464000000, 1238], weekly_low=[1642896000000, 828]
        ),
        23: WeeklyData(
            weekly_high=[1642377600000, 1323], weekly_low=[1641859200000, 1122]
        ),
        24: WeeklyData(
            weekly_high=[1641254400000, 1371], weekly_low=[1641686400000, 1108]
        ),
        25: WeeklyData(
            weekly_high=[1640649600000, 1433], weekly_low=[1640995200000, 1271]
        ),
        26: WeeklyData(
            weekly_high=[1640563200000, 1408], weekly_low=[1640044800000, 1100]
        ),
        27: WeeklyData(
            weekly_high=[1639872000000, 1186], weekly_low=[1639440000000, 1074]
        ),
        28: WeeklyData(
            weekly_high=[1639008000000, 1403], weekly_low=[1639180800000, 1152]
        ),
        29: WeeklyData(
            weekly_high=[1638489600000, 1680], weekly_low=[1638748800000, 1241]
        ),
        30: WeeklyData(
            weekly_high=[1637712000000, 1653], weekly_low=[1637971200000, 1443]
        ),
        31: WeeklyData(
            weekly_high=[1637020800000, 1792], weekly_low=[1637280000000, 1487]
        ),
        32: WeeklyData(
            weekly_high=[1636502400000, 1957], weekly_low=[1636761600000, 1834]
        ),
        33: WeeklyData(
            weekly_high=[1635984000000, 1996], weekly_low=[1636243200000, 1867]
        ),
        34: WeeklyData(
            weekly_high=[1635206400000, 2008], weekly_low=[1635379200000, 1820]
        ),
        35: WeeklyData(
            weekly_high=[1634774400000, 2024], weekly_low=[1634601600000, 1914]
        ),
        36: WeeklyData(
            weekly_high=[1634428800000, 2031], weekly_low=[1634083200000, 1766]
        ),
        37: WeeklyData(
            weekly_high=[1633651200000, 1915], weekly_low=[1633910400000, 1826]
        ),
        38: WeeklyData(
            weekly_high=[1633219200000, 1941], weekly_low=[1632787200000, 1653]
        ),
        39: WeeklyData(
            weekly_high=[1632700800000, 1763], weekly_low=[1632268800000, 1393]
        ),
        40: WeeklyData(
            weekly_high=[1631750400000, 2008], weekly_low=[1631577600000, 1675]
        ),
        41: WeeklyData(
            weekly_high=[1630972800000, 2119], weekly_low=[1631318400000, 1635]
        ),
        42: WeeklyData(
            weekly_high=[1630540800000, 2265], weekly_low=[1630368000000, 1973]
        ),
        43: WeeklyData(
            weekly_high=[1629763200000, 2131], weekly_low=[1630022400000, 1917]
        ),
        44: WeeklyData(
            weekly_high=[1629158400000, 2166], weekly_low=[1629244800000, 1959]
        ),
        45: WeeklyData(
            weekly_high=[1628899200000, 2265], weekly_low=[1628812800000, 2081]
        ),
        46: WeeklyData(
            weekly_high=[1628380800000, 2100], weekly_low=[1628035200000, 1589]
        ),
        47: WeeklyData(
            weekly_high=[1627862400000, 1640], weekly_low=[1627344000000, 1380]
        ),
        48: WeeklyData(
            weekly_high=[1627084800000, 1386], weekly_low=[1626825600000, 1090]
        ),
        49: WeeklyData(
            weekly_high=[1626134400000, 1464], weekly_low=[1626566400000, 1202]
        ),
        50: WeeklyData(
            weekly_high=[1625702400000, 1676], weekly_low=[1625529600000, 1503]
        ),
        51: WeeklyData(
            weekly_high=[1625443200000, 1554], weekly_low=[1624924800000, 1318]
        ),
        52: WeeklyData(
            weekly_high=[1624579200000, 1340], weekly_low=[1624320000000, 1183]
        ),
        53: WeeklyData(
            weekly_high=[1623715200000, 1775], weekly_low=[1624147200000, 1474]
        ),
        54: WeeklyData(
            weekly_high=[1623283200000, 1837], weekly_low=[1623542400000, 1565]
        ),
        55: WeeklyData(
            weekly_high=[1622764800000, 2100], weekly_low=[1622937600000, 1868]
        ),
        56: WeeklyData(
            weekly_high=[1622073600000, 2126], weekly_low=[1622332800000, 1678]
        ),
        57: WeeklyData(
            weekly_high=[1621382400000, 2576], weekly_low=[1621814400000, 1233]
        ),
        58: WeeklyData(
            weekly_high=[1621036800000, 2947], weekly_low=[1621209600000, 2669]
        ),
        59: WeeklyData(
            weekly_high=[1620172800000, 3163], weekly_low=[1620604800000, 2893]
        ),
        60: WeeklyData(
            weekly_high=[1619654400000, 3178], weekly_low=[1619481600000, 2838]
        ),
        61: WeeklyData(
            weekly_high=[1619136000000, 2592], weekly_low=[1619308800000, 2249]
        ),
        62: WeeklyData(
            weekly_high=[1618531200000, 2829], weekly_low=[1618790400000, 2369]
        ),
        63: WeeklyData(
            weekly_high=[1617753600000, 2303], weekly_low=[1617840000000, 2129]
        ),
        64: WeeklyData(
            weekly_high=[1617580800000, 2275], weekly_low=[1617235200000, 2052]
        ),
        65: WeeklyData(
            weekly_high=[1616457600000, 2388], weekly_low=[1616716800000, 1927]
        ),
        66: WeeklyData(
            weekly_high=[1616198400000, 2406], weekly_low=[1615852800000, 2151]
        ),
        67: WeeklyData(
            weekly_high=[1615248000000, 2455], weekly_low=[1615420800000, 2249]
        ),
        68: WeeklyData(
            weekly_high=[1615161600000, 2533], weekly_low=[1614816000000, 1860]
        ),
        69: WeeklyData(
            weekly_high=[1614038400000, 2011], weekly_low=[1614556800000, 1632]
        ),
        70: WeeklyData(
            weekly_high=[1613952000000, 2104], weekly_low=[1613433600000, 1451]
        ),
        71: WeeklyData(
            weekly_high=[1613174400000, 1648], weekly_low=[1612828800000, 1411]
        ),
        72: WeeklyData(
            weekly_high=[1612569600000, 1546], weekly_low=[1612742400000, 1352]
        ),
        73: WeeklyData(
            weekly_high=[1612051200000, 1413], weekly_low=[1611619200000, 831]
        ),
        74: WeeklyData(
            weekly_high=[1611532800000, 876], weekly_low=[1611273600000, 557]
        ),
        75: WeeklyData(
            weekly_high=[1610928000000, 634], weekly_low=[1610409600000, 385]
        ),
        76: WeeklyData(
            weekly_high=[1609977600000, 468], weekly_low=[1609804800000, 384]
        ),
        77: WeeklyData(
            weekly_high=[1609718400000, 395], weekly_low=[1609286400000, 269]
        ),
        78: WeeklyData(
            weekly_high=[1608681600000, 278], weekly_low=[1608768000000, 245]
        ),
        79: WeeklyData(
            weekly_high=[1608422400000, 291], weekly_low=[1608076800000, 245]
        ),
        80: WeeklyData(
            weekly_high=[1607385600000, 277], weekly_low=[1607731200000, 218]
        ),
        81: WeeklyData(
            weekly_high=[1606953600000, 292], weekly_low=[1607126400000, 260]
        ),
        82: WeeklyData(
            weekly_high=[1606176000000, 308], weekly_low=[1606521600000, 245]
        ),
        83: WeeklyData(
            weekly_high=[1605657600000, 285], weekly_low=[1605744000000, 257]
        ),
        84: WeeklyData(
            weekly_high=[1605312000000, 289], weekly_low=[1604966400000, 197]
        ),
        85: WeeklyData(
            weekly_high=[1604880000000, 212], weekly_low=[1604534400000, 143]
        ),
        86: WeeklyData(
            weekly_high=[1603843200000, 207], weekly_low=[1604188800000, 168]
        ),
        87: WeeklyData(
            weekly_high=[1603152000000, 232], weekly_low=[1603670400000, 204]
        ),
        88: WeeklyData(
            weekly_high=[1602547200000, 253], weekly_low=[1602892800000, 222]
        ),
        89: WeeklyData(
            weekly_high=[1602288000000, 248], weekly_low=[1602028800000, 198]
        ),
        90: WeeklyData(
            weekly_high=[1601424000000, 320], weekly_low=[1601856000000, 272]
        ),
        91: WeeklyData(
            weekly_high=[1600992000000, 378], weekly_low=[1600819200000, 287]
        ),
        92: WeeklyData(
            weekly_high=[1600473600000, 522], weekly_low=[1600387200000, 253]
        ),
    },
    "cardano": {
        1: WeeklyData(weekly_high=[1655337600000, 41], weekly_low=[1655624867000, 35]),
        2: WeeklyData(weekly_high=[1654732800000, 49], weekly_low=[1655078400000, 39]),
        3: WeeklyData(weekly_high=[1654041600000, 48], weekly_low=[1654128000000, 42]),
        4: WeeklyData(weekly_high=[1653436800000, 40], weekly_low=[1653696000000, 35]),
        5: WeeklyData(weekly_high=[1652832000000, 44], weekly_low=[1652918400000, 39]),
        6: WeeklyData(weekly_high=[1652227200000, 48], weekly_low=[1652400000000, 36]),
        7: WeeklyData(weekly_high=[1651708800000, 68], weekly_low=[1652054400000, 57]),
        8: WeeklyData(weekly_high=[1650931200000, 68], weekly_low=[1651363200000, 58]),
        9: WeeklyData(weekly_high=[1650412800000, 72], weekly_low=[1650844800000, 67]),
        10: WeeklyData(weekly_high=[1649894400000, 74], weekly_low=[1649721600000, 69]),
        11: WeeklyData(weekly_high=[1649116800000, 91], weekly_low=[1649462400000, 78]),
        12: WeeklyData(weekly_high=[1648684800000, 90], weekly_low=[1648771200000, 86]),
        13: WeeklyData(weekly_high=[1648425600000, 89], weekly_low=[1647907200000, 69]),
        14: WeeklyData(weekly_high=[1647734400000, 68], weekly_low=[1647388800000, 61]),
        15: WeeklyData(weekly_high=[1646870400000, 64], weekly_low=[1647043200000, 60]),
        16: WeeklyData(weekly_high=[1646179200000, 73], weekly_low=[1646611200000, 63]),
        17: WeeklyData(weekly_high=[1645833600000, 67], weekly_low=[1645488000000, 64]),
        18: WeeklyData(weekly_high=[1644969600000, 83], weekly_low=[1645401600000, 69]),
        19: WeeklyData(weekly_high=[1644278400000, 89], weekly_low=[1644796800000, 78]),
        20: WeeklyData(weekly_high=[1644192000000, 85], weekly_low=[1643846400000, 77]),
        21: WeeklyData(weekly_high=[1643241600000, 80], weekly_low=[1643587200000, 77]),
        22: WeeklyData(
            weekly_high=[1642464000000, 118], weekly_low=[1642896000000, 79]
        ),
        23: WeeklyData(
            weekly_high=[1642377600000, 104], weekly_low=[1641859200000, 83]
        ),
        24: WeeklyData(weekly_high=[1641254400000, 98], weekly_low=[1641772800000, 87]),
        25: WeeklyData(
            weekly_high=[1640649600000, 114], weekly_low=[1640995200000, 97]
        ),
        26: WeeklyData(
            weekly_high=[1640304000000, 110], weekly_low=[1640044800000, 94]
        ),
        27: WeeklyData(
            weekly_high=[1639612800000, 100], weekly_low=[1639440000000, 92]
        ),
        28: WeeklyData(
            weekly_high=[1638835200000, 106], weekly_low=[1639180800000, 92]
        ),
        29: WeeklyData(
            weekly_high=[1638489600000, 128], weekly_low=[1638748800000, 103]
        ),
        30: WeeklyData(
            weekly_high=[1637625600000, 132], weekly_low=[1637971200000, 115]
        ),
        31: WeeklyData(
            weekly_high=[1637020800000, 150], weekly_low=[1637280000000, 132]
        ),
        32: WeeklyData(
            weekly_high=[1636502400000, 168], weekly_low=[1636934400000, 152]
        ),
        33: WeeklyData(
            weekly_high=[1635984000000, 153], weekly_low=[1635811200000, 146]
        ),
        34: WeeklyData(
            weekly_high=[1635206400000, 161], weekly_low=[1635379200000, 144]
        ),
        35: WeeklyData(
            weekly_high=[1634774400000, 164], weekly_low=[1634688000000, 158]
        ),
        36: WeeklyData(
            weekly_high=[1634342400000, 166], weekly_low=[1634083200000, 159]
        ),
        37: WeeklyData(
            weekly_high=[1633651200000, 170], weekly_low=[1633392000000, 163]
        ),
        38: WeeklyData(
            weekly_high=[1633305600000, 167], weekly_low=[1632873600000, 151]
        ),
        39: WeeklyData(
            weekly_high=[1632441600000, 171], weekly_low=[1632268800000, 145]
        ),
        40: WeeklyData(
            weekly_high=[1631750400000, 183], weekly_low=[1632096000000, 168]
        ),
        41: WeeklyData(
            weekly_high=[1630972800000, 207], weekly_low=[1631318400000, 174]
        ),
        42: WeeklyData(
            weekly_high=[1630627200000, 216], weekly_low=[1630368000000, 200]
        ),
        43: WeeklyData(
            weekly_high=[1629763200000, 215], weekly_low=[1630022400000, 191]
        ),
        44: WeeklyData(
            weekly_high=[1629676800000, 197], weekly_low=[1629244800000, 142]
        ),
        45: WeeklyData(
            weekly_high=[1628985600000, 162], weekly_low=[1628553600000, 110]
        ),
        46: WeeklyData(
            weekly_high=[1628380800000, 109], weekly_low=[1627948800000, 97]
        ),
        47: WeeklyData(weekly_high=[1627776000000, 98], weekly_low=[1627344000000, 93]),
        48: WeeklyData(weekly_high=[1627257600000, 91], weekly_low=[1626825600000, 79]),
        49: WeeklyData(weekly_high=[1626134400000, 98], weekly_low=[1626480000000, 87]),
        50: WeeklyData(
            weekly_high=[1625616000000, 105], weekly_low=[1625961600000, 99]
        ),
        51: WeeklyData(
            weekly_high=[1625443200000, 108], weekly_low=[1624924800000, 98]
        ),
        52: WeeklyData(
            weekly_high=[1624579200000, 100], weekly_low=[1624406400000, 85]
        ),
        53: WeeklyData(
            weekly_high=[1623715200000, 115], weekly_low=[1624147200000, 103]
        ),
        54: WeeklyData(
            weekly_high=[1623283200000, 118], weekly_low=[1623456000000, 105]
        ),
        55: WeeklyData(
            weekly_high=[1622764800000, 134], weekly_low=[1622937600000, 120]
        ),
        56: WeeklyData(
            weekly_high=[1622073600000, 129], weekly_low=[1622332800000, 102]
        ),
        57: WeeklyData(
            weekly_high=[1621296000000, 148], weekly_low=[1621814400000, 96]
        ),
        58: WeeklyData(
            weekly_high=[1621209600000, 167], weekly_low=[1620864000000, 115]
        ),
        59: WeeklyData(
            weekly_high=[1620604800000, 130], weekly_low=[1620172800000, 94]
        ),
        60: WeeklyData(
            weekly_high=[1619827200000, 100], weekly_low=[1619481600000, 92]
        ),
        61: WeeklyData(weekly_high=[1618963200000, 95], weekly_low=[1619395200000, 81]),
        62: WeeklyData(
            weekly_high=[1618531200000, 110], weekly_low=[1618790400000, 95]
        ),
        63: WeeklyData(weekly_high=[1618185600000, 94], weekly_low=[1617840000000, 87]),
        64: WeeklyData(weekly_high=[1617148800000, 88], weekly_low=[1617494400000, 85]),
        65: WeeklyData(weekly_high=[1616803200000, 87], weekly_low=[1616630400000, 77]),
        66: WeeklyData(weekly_high=[1616025600000, 99], weekly_low=[1615852800000, 74]),
        67: WeeklyData(weekly_high=[1615334400000, 86], weekly_low=[1615593600000, 75]),
        68: WeeklyData(weekly_high=[1614643200000, 95], weekly_low=[1614902400000, 81]),
        69: WeeklyData(weekly_high=[1614470400000, 98], weekly_low=[1614124800000, 69]),
        70: WeeklyData(weekly_high=[1613865600000, 81], weekly_low=[1613433600000, 62]),
        71: WeeklyData(weekly_high=[1613088000000, 67], weekly_low=[1612828800000, 50]),
        72: WeeklyData(weekly_high=[1612742400000, 48], weekly_low=[1612224000000, 29]),
        73: WeeklyData(weekly_high=[1612051200000, 26], weekly_low=[1611792000000, 22]),
        74: WeeklyData(weekly_high=[1611187200000, 27], weekly_low=[1611273600000, 22]),
        75: WeeklyData(weekly_high=[1610928000000, 27], weekly_low=[1610409600000, 20]),
        76: WeeklyData(weekly_high=[1610236800000, 24], weekly_low=[1609804800000, 15]),
        77: WeeklyData(weekly_high=[1609718400000, 14], weekly_low=[1609545600000, 12]),
        78: WeeklyData(weekly_high=[1609027200000, 11], weekly_low=[1608768000000, 10]),
        79: WeeklyData(weekly_high=[1608163200000, 12], weekly_low=[1608076800000, 11]),
        80: WeeklyData(weekly_high=[1607385600000, 11], weekly_low=[1607731200000, 10]),
        81: WeeklyData(weekly_high=[1606780800000, 12], weekly_low=[1607126400000, 11]),
        82: WeeklyData(weekly_high=[1606262400000, 12], weekly_low=[1606435200000, 10]),
        83: WeeklyData(weekly_high=[1606089600000, 10], weekly_low=[1605571200000, 7]),
        84: WeeklyData(weekly_high=[1605312000000, 7], weekly_low=[1605484800000, 7]),
        85: WeeklyData(weekly_high=[1604707200000, 8], weekly_low=[1604361600000, 6]),
        86: WeeklyData(weekly_high=[1603756800000, 7], weekly_low=[1604188800000, 6]),
        87: WeeklyData(weekly_high=[1603411200000, 8], weekly_low=[1603238400000, 7]),
        88: WeeklyData(weekly_high=[1602547200000, 8], weekly_low=[1602892800000, 7]),
        89: WeeklyData(weekly_high=[1602460800000, 7], weekly_low=[1602028800000, 6]),
        90: WeeklyData(weekly_high=[1601424000000, 7], weekly_low=[1601683200000, 6]),
        91: WeeklyData(weekly_high=[1601251200000, 7], weekly_low=[1600905600000, 5]),
        92: WeeklyData(weekly_high=[1600128000000, 7], weekly_low=[1600646400000, 6]),
        93: WeeklyData(weekly_high=[1599955200000, 7], weekly_low=[1599609600000, 6]),
        94: WeeklyData(weekly_high=[1599004800000, 9], weekly_low=[1599350400000, 6]),
        95: WeeklyData(weekly_high=[1598313600000, 9], weekly_low=[1598572800000, 7]),
        96: WeeklyData(weekly_high=[1597708800000, 10], weekly_low=[1598227200000, 9]),
        97: WeeklyData(weekly_high=[1597104000000, 10], weekly_low=[1597276800000, 10]),
        98: WeeklyData(weekly_high=[1596931200000, 10], weekly_low=[1596499200000, 10]),
        99: WeeklyData(weekly_high=[1595980800000, 11], weekly_low=[1596412800000, 10]),
        100: WeeklyData(weekly_high=[1595808000000, 11], weekly_low=[1595289600000, 8]),
        101: WeeklyData(weekly_high=[1594771200000, 9], weekly_low=[1595030400000, 9]),
        102: WeeklyData(weekly_high=[1594252800000, 9], weekly_low=[1594080000000, 7]),
        103: WeeklyData(weekly_high=[1593907200000, 7], weekly_low=[1593561600000, 6]),
        104: WeeklyData(weekly_high=[1592870400000, 6], weekly_low=[1593302400000, 5]),
        105: WeeklyData(weekly_high=[1592438400000, 6], weekly_low=[1592265600000, 5]),
        106: WeeklyData(weekly_high=[1591660800000, 6], weekly_low=[1591920000000, 5]),
        107: WeeklyData(weekly_high=[1591315200000, 6], weekly_low=[1591142400000, 5]),
        108: WeeklyData(weekly_high=[1590883200000, 5], weekly_low=[1590537600000, 4]),
        109: WeeklyData(weekly_high=[1590019200000, 4], weekly_low=[1590364800000, 3]),
        110: WeeklyData(weekly_high=[1589500800000, 3], weekly_low=[1589241600000, 3]),
        111: WeeklyData(weekly_high=[1588896000000, 3], weekly_low=[1589155200000, 3]),
        112: WeeklyData(weekly_high=[1588204800000, 3], weekly_low=[1588032000000, 3]),
        113: WeeklyData(weekly_high=[1587945600000, 3], weekly_low=[1587427200000, 2]),
        114: WeeklyData(weekly_high=[1587254400000, 2], weekly_low=[1586995200000, 2]),
        115: WeeklyData(weekly_high=[1586476800000, 2], weekly_low=[1586649600000, 2]),
        116: WeeklyData(weekly_high=[1586044800000, 2], weekly_low=[1585612800000, 2]),
        117: WeeklyData(weekly_high=[1585094400000, 2], weekly_low=[1585526400000, 2]),
        118: WeeklyData(weekly_high=[1584662400000, 2], weekly_low=[1584403200000, 1]),
        119: WeeklyData(weekly_high=[1583798400000, 3], weekly_low=[1584057600000, 1]),
        120: WeeklyData(weekly_high=[1583539200000, 3], weekly_low=[1583712000000, 3]),
        121: WeeklyData(weekly_high=[1582588800000, 4], weekly_low=[1583107200000, 3]),
        122: WeeklyData(weekly_high=[1582070400000, 4], weekly_low=[1582243200000, 4]),
        123: WeeklyData(weekly_high=[1581724800000, 5], weekly_low=[1581379200000, 4]),
        124: WeeklyData(weekly_high=[1581292800000, 4], weekly_low=[1580860800000, 3]),
        125: WeeklyData(weekly_high=[1580428800000, 3], weekly_low=[1580169600000, 3]),
        126: WeeklyData(weekly_high=[1579651200000, 3], weekly_low=[1579564800000, 3]),
        127: WeeklyData(weekly_high=[1579392000000, 3], weekly_low=[1578960000000, 2]),
        128: WeeklyData(weekly_high=[1578441600000, 2], weekly_low=[1578614400000, 2]),
        129: WeeklyData(weekly_high=[1578268800000, 2], weekly_low=[1578009600000, 2]),
        130: WeeklyData(weekly_high=[1577664000000, 2], weekly_low=[1577491200000, 2]),
        131: WeeklyData(weekly_high=[1577059200000, 2], weekly_low=[1576627200000, 2]),
        132: WeeklyData(weekly_high=[1575936000000, 2], weekly_low=[1576368000000, 2]),
        133: WeeklyData(weekly_high=[1575849600000, 2], weekly_low=[1575504000000, 2]),
        134: WeeklyData(weekly_high=[1575072000000, 2], weekly_low=[1574726400000, 2]),
        135: WeeklyData(weekly_high=[1574121600000, 3], weekly_low=[1574640000000, 2]),
        136: WeeklyData(weekly_high=[1574035200000, 3], weekly_low=[1573776000000, 3]),
        137: WeeklyData(weekly_high=[1573084800000, 3], weekly_low=[1573257600000, 3]),
        138: WeeklyData(weekly_high=[1572393600000, 3], weekly_low=[1572566400000, 2]),
        139: WeeklyData(weekly_high=[1572220800000, 2], weekly_low=[1571875200000, 2]),
        140: WeeklyData(weekly_high=[1571097600000, 2], weekly_low=[1571443200000, 2]),
        141: WeeklyData(weekly_high=[1570665600000, 3], weekly_low=[1570838400000, 2]),
        142: WeeklyData(weekly_high=[1570320000000, 2], weekly_low=[1569888000000, 2]),
        143: WeeklyData(weekly_high=[1569283200000, 3], weekly_low=[1569801600000, 2]),
        144: WeeklyData(weekly_high=[1568851200000, 3], weekly_low=[1568678400000, 3]),
        145: WeeklyData(weekly_high=[1568073600000, 3], weekly_low=[1568246400000, 3]),
        146: WeeklyData(weekly_high=[1567555200000, 3], weekly_low=[1567814400000, 3]),
        147: WeeklyData(weekly_high=[1566864000000, 3], weekly_low=[1567382400000, 3]),
        148: WeeklyData(weekly_high=[1566691200000, 3], weekly_low=[1566432000000, 3]),
        149: WeeklyData(weekly_high=[1565654400000, 3], weekly_low=[1566000000000, 3]),
        150: WeeklyData(weekly_high=[1565049600000, 4], weekly_low=[1565395200000, 3]),
        151: WeeklyData(weekly_high=[1564617600000, 4], weekly_low=[1564963200000, 3]),
        152: WeeklyData(weekly_high=[1564185600000, 4], weekly_low=[1563926400000, 3]),
        153: WeeklyData(weekly_high=[1563667200000, 4], weekly_low=[1563321600000, 3]),
        154: WeeklyData(weekly_high=[1562630400000, 5], weekly_low=[1563148800000, 4]),
        155: WeeklyData(weekly_high=[1562025600000, 5], weekly_low=[1562371200000, 5]),
        156: WeeklyData(weekly_high=[1561593600000, 6], weekly_low=[1561939200000, 5]),
        157: WeeklyData(weekly_high=[1561334400000, 6], weekly_low=[1561075200000, 6]),
        158: WeeklyData(weekly_high=[1560384000000, 6], weekly_low=[1560211200000, 5]),
        159: WeeklyData(weekly_high=[1559606400000, 6], weekly_low=[1560124800000, 5]),
        160: WeeklyData(weekly_high=[1559520000000, 6], weekly_low=[1559260800000, 5]),
        161: WeeklyData(weekly_high=[1558915200000, 5], weekly_low=[1558569600000, 5]),
        162: WeeklyData(weekly_high=[1557964800000, 6], weekly_low=[1557792000000, 5]),
        163: WeeklyData(weekly_high=[1557619200000, 5], weekly_low=[1557446400000, 4]),
        164: WeeklyData(weekly_high=[1556668800000, 4], weekly_low=[1556582400000, 4]),
        165: WeeklyData(weekly_high=[1555977600000, 5], weekly_low=[1556496000000, 4]),
        166: WeeklyData(weekly_high=[1555459200000, 5], weekly_low=[1555891200000, 5]),
        167: WeeklyData(weekly_high=[1554940800000, 6], weekly_low=[1555027200000, 5]),
        168: WeeklyData(weekly_high=[1554508800000, 6], weekly_low=[1554163200000, 5]),
        169: WeeklyData(weekly_high=[1553904000000, 4], weekly_low=[1553558400000, 4]),
        170: WeeklyData(weekly_high=[1553385600000, 4], weekly_low=[1552953600000, 3]),
        171: WeeklyData(weekly_high=[1552780800000, 3], weekly_low=[1552521600000, 3]),
        172: WeeklyData(weekly_high=[1552176000000, 3], weekly_low=[1551744000000, 2]),
        173: WeeklyData(weekly_high=[1551139200000, 3], weekly_low=[1551657600000, 2]),
        174: WeeklyData(weekly_high=[1550966400000, 3], weekly_low=[1551052800000, 2]),
        175: WeeklyData(weekly_high=[1549929600000, 2], weekly_low=[1550188800000, 2]),
        176: WeeklyData(weekly_high=[1549843200000, 3], weekly_low=[1549584000000, 2]),
        177: WeeklyData(weekly_high=[1548892800000, 2], weekly_low=[1548979200000, 2]),
        178: WeeklyData(weekly_high=[1548201600000, 3], weekly_low=[1548633600000, 2]),
        179: WeeklyData(weekly_high=[1547942400000, 3], weekly_low=[1547596800000, 3]),
        180: WeeklyData(weekly_high=[1547078400000, 3], weekly_low=[1547424000000, 2]),
        181: WeeklyData(weekly_high=[1546819200000, 3], weekly_low=[1546300800000, 2]),
        182: WeeklyData(weekly_high=[1545696000000, 3], weekly_low=[1545955200000, 2]),
        183: WeeklyData(weekly_high=[1545609600000, 3], weekly_low=[1545091200000, 2]),
        184: WeeklyData(weekly_high=[1544659200000, 2], weekly_low=[1544918400000, 1]),
        185: WeeklyData(weekly_high=[1543881600000, 2], weekly_low=[1544227200000, 2]),
        186: WeeklyData(weekly_high=[1543449600000, 2], weekly_low=[1543276800000, 2]),
        187: WeeklyData(weekly_high=[1542672000000, 3], weekly_low=[1543190400000, 2]),
        188: WeeklyData(weekly_high=[1542067200000, 5], weekly_low=[1542499200000, 4]),
        189: WeeklyData(weekly_high=[1541548800000, 5], weekly_low=[1541808000000, 5]),
        190: WeeklyData(weekly_high=[1541376000000, 5], weekly_low=[1540857600000, 5]),
        191: WeeklyData(weekly_high=[1540252800000, 5], weekly_low=[1540684800000, 5]),
        192: WeeklyData(weekly_high=[1539820800000, 5], weekly_low=[1539907200000, 5]),
        193: WeeklyData(weekly_high=[1539129600000, 6], weekly_low=[1539302400000, 5]),
        194: WeeklyData(weekly_high=[1538956800000, 6], weekly_low=[1538611200000, 5]),
        195: WeeklyData(weekly_high=[1538092800000, 6], weekly_low=[1538006400000, 5]),
        196: WeeklyData(weekly_high=[1537747200000, 6], weekly_low=[1537228800000, 4]),
        197: WeeklyData(weekly_high=[1536624000000, 5], weekly_low=[1536796800000, 4]),
        198: WeeklyData(weekly_high=[1536105600000, 7], weekly_low=[1536537600000, 5]),
        199: WeeklyData(weekly_high=[1535846400000, 7], weekly_low=[1535414400000, 7]),
        200: WeeklyData(weekly_high=[1534896000000, 6], weekly_low=[1534982400000, 6]),
        201: WeeklyData(weekly_high=[1534550400000, 7], weekly_low=[1534291200000, 6]),
        202: WeeklyData(weekly_high=[1533600000000, 8], weekly_low=[1534032000000, 7]),
        203: WeeklyData(weekly_high=[1532995200000, 10], weekly_low=[1533427200000, 8]),
        204: WeeklyData(
            weekly_high=[1532476800000, 11], weekly_low=[1532908800000, 11]
        ),
        205: WeeklyData(
            weekly_high=[1532044800000, 12], weekly_low=[1531785600000, 10]
        ),
        206: WeeklyData(weekly_high=[1531699200000, 9], weekly_low=[1531440000000, 8]),
        207: WeeklyData(weekly_high=[1530576000000, 10], weekly_low=[1531094400000, 9]),
        208: WeeklyData(weekly_high=[1530489600000, 9], weekly_low=[1530230400000, 8]),
        209: WeeklyData(weekly_high=[1529452800000, 11], weekly_low=[1529884800000, 8]),
        210: WeeklyData(
            weekly_high=[1528761600000, 12], weekly_low=[1528934400000, 10]
        ),
        211: WeeklyData(
            weekly_high=[1528243200000, 14], weekly_low=[1528675200000, 11]
        ),
        212: WeeklyData(
            weekly_high=[1527984000000, 15], weekly_low=[1527552000000, 11]
        ),
        213: WeeklyData(
            weekly_high=[1526947200000, 16], weekly_low=[1527465600000, 13]
        ),
        214: WeeklyData(
            weekly_high=[1526342400000, 18], weekly_low=[1526774400000, 16]
        ),
        215: WeeklyData(
            weekly_high=[1525737600000, 22], weekly_low=[1526083200000, 17]
        ),
        216: WeeklyData(
            weekly_high=[1525392000000, 24], weekly_low=[1525132800000, 22]
        ),
        217: WeeklyData(
            weekly_high=[1525046400000, 24], weekly_low=[1524700800000, 18]
        ),
        218: WeeklyData(
            weekly_high=[1524268800000, 19], weekly_low=[1524009600000, 15]
        ),
        219: WeeklyData(weekly_high=[1523836800000, 14], weekly_low=[1523318400000, 9]),
        220: WeeklyData(weekly_high=[1522800000000, 11], weekly_low=[1523059200000, 9]),
        221: WeeklyData(weekly_high=[1522108800000, 10], weekly_low=[1522368000000, 9]),
        222: WeeklyData(
            weekly_high=[1521676800000, 14], weekly_low=[1522022400000, 12]
        ),
        223: WeeklyData(
            weekly_high=[1520899200000, 14], weekly_low=[1521417600000, 10]
        ),
        224: WeeklyData(
            weekly_high=[1520294400000, 19], weekly_low=[1520726400000, 13]
        ),
        225: WeeklyData(
            weekly_high=[1519776000000, 21], weekly_low=[1520121600000, 18]
        ),
        226: WeeklyData(
            weekly_high=[1519084800000, 24], weekly_low=[1519516800000, 19]
        ),
        227: WeeklyData(
            weekly_high=[1518912000000, 26], weekly_low=[1518566400000, 22]
        ),
        228: WeeklyData(
            weekly_high=[1518307200000, 24], weekly_low=[1517875200000, 19]
        ),
        229: WeeklyData(
            weekly_high=[1517270721088, 37], weekly_low=[1517788800000, 25]
        ),
        230: WeeklyData(
            weekly_high=[1516838400000, 40], weekly_low=[1516665600000, 36]
        ),
        231: WeeklyData(
            weekly_high=[1516406400000, 46], weekly_low=[1516579200000, 37]
        ),
        232: WeeklyData(
            weekly_high=[1515715200000, 61], weekly_low=[1515628800000, 46]
        ),
        233: WeeklyData(
            weekly_high=[1515024000000, 74], weekly_low=[1514851200000, 51]
        ),
        234: WeeklyData(
            weekly_high=[1514678400000, 49], weekly_low=[1514419200000, 27]
        ),
        235: WeeklyData(
            weekly_high=[1513641600000, 35], weekly_low=[1514073600000, 26]
        ),
        236: WeeklyData(weekly_high=[1513555200000, 32], weekly_low=[1513036800000, 8]),
        237: WeeklyData(weekly_high=[1512432000000, 8], weekly_low=[1512864000000, 7]),
        238: WeeklyData(weekly_high=[1512345600000, 8], weekly_low=[1511913600000, 5]),
        239: WeeklyData(weekly_high=[1511740800000, 3], weekly_low=[1511395200000, 1]),
        240: WeeklyData(weekly_high=[1511136000000, 1], weekly_low=[1510876800000, 1]),
        241: WeeklyData(weekly_high=[1510185600000, 2], weekly_low=[1510012800000, 1]),
        242: WeeklyData(weekly_high=[1509408000000, 1], weekly_low=[1509580800000, 1]),
        243: WeeklyData(weekly_high=[1509235200000, 1], weekly_low=[1509148800000, 1]),
        244: WeeklyData(weekly_high=[1508457600000, 1], weekly_low=[1508716800000, 1]),
    },
}

# %%
import requests
from constants import (
    COIN_METADATA,
    CURRENT_COIN_DATA,
    WINDOW_OF_DAYS,
)
coin_ids_list = ["uniswap", "cardano"]
coin_ids = ",".join(coin_ids_list)
current_price = requests.get(CURRENT_COIN_DATA.format(coin_ids)).json()

# %%
for coin, weekly_data in data.items():
    print(coin, sum(weekly_data.keys()))
# Out:
# uniswap 4278
# cardano 29890

# %%
current_price
# Out:
# {'cardano': {'inr': 36.08}, 'uniswap': {'inr': 301.52}}

# %%
for coin, price_details in current_price.items():
    coin_price = price_details["inr"]
    max_score = sum(data[coin].keys())
    print(f"coin {coin} max_score {max_score} coin_price {coin_price}")
    for week_number, weekly_high_low in data[coin].items():
        if weekly_high_low.weekly_low[1] >= coin_price:
            print(week_number, weekly_high_low)
# Out:
# coin cardano max_score 29890 coin_price 36.08
# 2 weekly_high=[1654732800000, 49] weekly_low=[1655078400000, 39]
# 3 weekly_high=[1654041600000, 48] weekly_low=[1654128000000, 42]
# 5 weekly_high=[1652832000000, 44] weekly_low=[1652918400000, 39]
# 7 weekly_high=[1651708800000, 68] weekly_low=[1652054400000, 57]
# 8 weekly_high=[1650931200000, 68] weekly_low=[1651363200000, 58]
# 9 weekly_high=[1650412800000, 72] weekly_low=[1650844800000, 67]
# 10 weekly_high=[1649894400000, 74] weekly_low=[1649721600000, 69]
# 11 weekly_high=[1649116800000, 91] weekly_low=[1649462400000, 78]
# 12 weekly_high=[1648684800000, 90] weekly_low=[1648771200000, 86]
# 13 weekly_high=[1648425600000, 89] weekly_low=[1647907200000, 69]
# 14 weekly_high=[1647734400000, 68] weekly_low=[1647388800000, 61]
# 15 weekly_high=[1646870400000, 64] weekly_low=[1647043200000, 60]
# 16 weekly_high=[1646179200000, 73] weekly_low=[1646611200000, 63]
# 17 weekly_high=[1645833600000, 67] weekly_low=[1645488000000, 64]
# ...
